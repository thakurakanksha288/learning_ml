# %% [markdown]
# <a href="https://colab.research.google.com/github/thakurakanksha288/learning_ml/blob/main/data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/building_energy_data_extended.csv')
df1=pd.read_csv("/content/db_building_A.csv", encoding='latin1')
df2=pd.read_csv("/content/db_building_B.csv", encoding='latin1')
df.head()
# Out:
#              Timestamp Building_ID  Energy_Usage (kWh)  Temperature (°C)  \
# 0  2025-01-01 00:00:00        B001              121.30             -7.20
# 1  2025-01-01 01:00:00        B001              230.76             12.62
# 2  2025-01-01 02:00:00        B001              187.21             -1.33
# 3  2025-01-01 03:00:00        B001              262.23              0.24
# 4  2025-01-01 04:00:00        B001              472.97              5.44
#
#    Humidity (%) Building_Type Occupancy_Level
# 0         79.36    Industrial             Low
# 1         80.37    Industrial            High
# 2         37.74    Industrial            High
# 3         39.97    Industrial            High
# 4         89.29    Industrial          Medium

# %%
df1.head()
# Out:
#                DATE   ENERGY  HDD18_3  CDD0  CDD10  PRECTOT   RH2M   T2M  \
# 0  01-01-2016 00:00      NaN    11.32  6.98    0.0     10.7  90.97  6.02
# 1  01-01-2016 01:00  113.415    11.32  6.98    0.0     10.7  90.97  6.02
# 2  01-01-2016 02:00  112.431    11.32  6.98    0.0     10.7  90.97  6.02
# 3  01-01-2016 03:00  111.517    11.32  6.98    0.0     10.7  90.97  6.02
# 4  01-01-2016 04:00  117.240    11.32  6.98    0.0     10.7  90.97  6.02
#
#    T2M_MIN  T2M_MAX  ...  \
# 0     1.74    12.23  ...
# 1     1.74    12.23  ...
# 2     1.74    12.23  ...
# 3     1.74    12.23  ...
# 4     1.74    12.23  ...
#
# ...

# %%
df2.head()
# Out:
#             DATE  ENERGY  HDD18_3  CDD10  CDD0  PRECTOT   RH2M  T2M_MAX  \
# 0  1/1/2016 0:00     NaN    11.32    0.0  6.98     10.7  90.97    12.23
# 1  1/1/2016 1:00  43.269    11.32    0.0  6.98     10.7  90.97    12.23
# 2  1/1/2016 2:00  45.159    11.32    0.0  6.98     10.7  90.97    12.23
# 3  1/1/2016 3:00  39.113    11.32    0.0  6.98     10.7  90.97    12.23
# 4  1/1/2016 4:00  36.299    11.32    0.0  6.98     10.7  90.97    12.23
#
#    T2M_MIN  ALLSKY   T2M  HOLIDAY
# 0     1.74     1.7  6.02        1
# 1     1.74     1.7  6.02        1
# 2     1.74     1.7  6.02        1
# 3     1.74     1.7  6.02        1
# 4     1.74     1.7  6.02        1

# %%
df.describe(include='all')
# Out:
#                   Timestamp Building_ID  Energy_Usage (kWh)  Temperature (°C)  \
# count                  7200        7200         7200.000000       7200.000000
# unique                  360          20                 NaN               NaN
# top     2025-01-15 23:00:00        B001                 NaN               NaN
# freq                     20         360                 NaN               NaN
# mean                    NaN         NaN          277.869099         12.450781
# std                     NaN         NaN          129.693860         13.033681
# min                     NaN         NaN           50.050000         -9.990000
# 25%                     NaN         NaN          165.965000          1.017500
# 50%                     NaN         NaN          279.410000         12.550000
# 75%                     NaN         NaN          387.527500         23.772500
# max                     NaN         NaN          499.920000         35.000000
#
# ...

# %%
df.dtypes
# Out:
# Timestamp              object
# Building_ID            object
# Energy_Usage (kWh)    float64
# Temperature (°C)      float64
# Humidity (%)          float64
# Building_Type          object
# Occupancy_Level        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7200 entries, 0 to 7199
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Timestamp           7200 non-null   object
#  1   Building_ID         7200 non-null   object
#  2   Energy_Usage (kWh)  7200 non-null   float64
#  3   Temperature (°C)    7200 non-null   float64
#  4   Humidity (%)        7200 non-null   float64
#  5   Building_Type       7200 non-null   object
#  6   Occupancy_Level     7200 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 393.9+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43848 entries, 0 to 43847
# Data columns (total 56 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                                                        Non-Null Count  Dtype
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43848 entries, 0 to 43847
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     43848 non-null  object
#  1   ENERGY   43781 non-null  float64
#  2   HDD18_3  43848 non-null  float64
#  3   CDD10    43848 non-null  float64
#  4   CDD0     43848 non-null  float64
#  5   PRECTOT  43848 non-null  float64
#  6   RH2M     43848 non-null  float64
#  7   T2M_MAX  43848 non-null  float64
#  8   T2M_MIN  43848 non-null  float64
#  9   ALLSKY   43704 non-null  float64
#  10  T2M      43848 non-null  float64
#  11  HOLIDAY  43848 non-null  int64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 4.0+ MB

# %%
df.replace("?",np.nan,inplace=True)
#for export and file to_csv

# %%
#how to deal with missing values
missing_data=df.isnull()
for column in df.columns:
  print(column)
  print(missing_data[column].value_counts())
  print("")
# Out:
# Timestamp
# Timestamp
# False    7200
# Name: count, dtype: int64
#
# Building_ID
# Building_ID
# False    7200
# Name: count, dtype: int64
#
# Energy_Usage (kWh)
# Energy_Usage (kWh)
# False    7200
# Name: count, dtype: int64
#
# Temperature (°C)
# Temperature (°C)
# False    7200
# Name: count, dtype: int64
#
# Humidity (%)
# Humidity (%)
# False    7200
# Name: count, dtype: int64
#
# Building_Type
# Building_Type
# False    7200
# Name: count, dtype: int64
#
# Occupancy_Level
# Occupancy_Level
# False    7200
# Name: count, dtype: int64

# %%
#target value mei se remove krdo
#changing the astype accordingly from object to floot or and according to your wish
#to get the most frequent wali values so what we do we find it with value_count()/idxmax() gives us the count of most maximum vaues
#we usuaully drop the most required columns values if they have a lot of outlier(dropna())

# %%
missing_data=df1.isnull()
for column in df1.columns:
  print(column)
  print(missing_data[column].value_counts())
  print("")
# Out:
# DATE
# DATE
# False    43848
# Name: count, dtype: int64
#
# ENERGY
# ENERGY
# False    43746
# True       102
# Name: count, dtype: int64
#
# HDD18_3
# HDD18_3
# False    43848
# Name: count, dtype: int64
#
# CDD0
# CDD0
# False    43848
# Name: count, dtype: int64
#
# CDD10
# CDD10
# False    43848
# Name: count, dtype: int64
#
# PRECTOT
# PRECTOT
# False    43848
# Name: count, dtype: int64
#
# RH2M
# RH2M
# False    43848
# Name: count, dtype: int64
#
# T2M
# T2M
# False    43848
# Name: count, dtype: int64
#
# T2M_MIN
# T2M_MIN
# False    43848
# Name: count, dtype: int64
#
# T2M_MAX
# T2M_MAX
# False    43848
# Name: count, dtype: int64
#
# ALLSKY
# ALLSKY
# False    43704
# True       144
# Name: count, dtype: int64
#
# HOLIDAY
# HOLIDAY
# False    43848
# Name: count, dtype: int64
#
# Unnamed: 12
# Unnamed: 12
# True    43848
# Name: count, dtype: int64
#
# ...

# %%
#learning with skilearn
#skilearn imputer for findind the miss values(simple imputer)
from sklearn.impute import SimpleImputer
imputer_mean=SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43848 entries, 0 to 43847
# Data columns (total 56 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                                                        Non-Null Count  Dtype
# ...

# %%
df1.dtypes
# Out:
# DATE                                                                                                                                                                                                                                                                                                                                                                                                                                             object
# ENERGY                                                                                                                                                                                                                                                                                                                                                                                                                                          float64
# ...

# %%
df.head()
# Out:
#              Timestamp Building_ID  Energy_Usage (kWh)  Temperature (°C)  \
# 0  2025-01-01 00:00:00        B001              121.30             -7.20
# 1  2025-01-01 01:00:00        B001              230.76             12.62
# 2  2025-01-01 02:00:00        B001              187.21             -1.33
# 3  2025-01-01 03:00:00        B001              262.23              0.24
# 4  2025-01-01 04:00:00        B001              472.97              5.44
#
#    Humidity (%) Building_Type Occupancy_Level
# 0         79.36    Industrial             Low
# 1         80.37    Industrial            High
# 2         37.74    Industrial            High
# 3         39.97    Industrial            High
# 4         89.29    Industrial          Medium

# %%
#data binding
df['Energy_Usage(KWh)']=df['Energy_Usage (kWh)'].astype(float)
df['Energy_Usage(KWh)'].dtype
# Out:
# dtype('float64')

# %%
import matplotlib.pyplot as plt
plt.hist(df['Energy_Usage(KWh)'])


plt.xlabel("Energy_Usage(KWh)")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#creating a bins
bins=np.linspace(min(df['Energy_Usage(KWh)']),max(df['Energy_Usage(KWh)']),4)
bins
# Out:
# array([ 50.05      , 200.00666667, 349.96333333, 499.92      ])

# %%
#creating bins

group_names=['low','medium','high']
df['Energy_Usage_binned']=pd.cut(df["Energy_Usage(KWh)"],bins,labels=group_names,include_lowest=True)
df[['Energy_Usage(KWh)','Energy_Usage_binned']].head(20)
# Out:
#     Energy_Usage(KWh) Energy_Usage_binned
# 0              121.30                 low
# 1              230.76              medium
# 2              187.21                 low
# 3              262.23              medium
# 4              472.97                high
# 5              198.15                 low
# 6              369.35                high
# 7              374.21                high
# 8               85.65                 low
# 9              260.47              medium
# 10             180.61                 low
# 11             305.79              medium
# 12             279.35              medium
# 13             326.78              medium
# 14              72.73                 low
# 15             114.27                 low
# 16             420.64                high
# 17             310.34              medium
# 18             210.99              medium
# 19             441.36                high

# %%
df['Energy_Usage_binned'].value_counts()
# Out:
# Energy_Usage_binned
# high      2464
# medium    2388
# low       2348
# Name: count, dtype: int64

# %%
plt.bar(group_names,df['Energy_Usage_binned'].value_counts())
plt.xlabel("energy_usage_binned")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
#catorgies values to be handling (why encoding)
#onehot-non relational and mmade for indenpent data(0-1)
#label encoding-unique values assigned to unique variables(as an incresement(ML associated power-independent values))


#dummy variables-onehot encoding

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df.head()
# Out:
#              Timestamp Building_ID  Energy_Usage (kWh)  Temperature (°C)  \
# 0  2025-01-01 00:00:00        B001              121.30             -7.20
# 1  2025-01-01 01:00:00        B001              230.76             12.62
# 2  2025-01-01 02:00:00        B001              187.21             -1.33
# 3  2025-01-01 03:00:00        B001              262.23              0.24
# 4  2025-01-01 04:00:00        B001              472.97              5.44
#
#    Humidity (%) Building_Type Occupancy_Level  Energy_Usage(KWh)  \
# 0         79.36    Industrial             Low             121.30
# 1         80.37    Industrial            High             230.76
# 2         37.74    Industrial            High             187.21
# 3         39.97    Industrial            High             262.23
# 4         89.29    Industrial          Medium             472.97
#
#   Energy_Usage_binned
# 0                 low
# 1              medium
# 2                 low
# 3              medium
# ...

# %%
#basically now dividing data into simple spaces and then using it to make predictiin
X=df.iloc[:,3:5]
#made features
y=df.iloc[:,2]
#predicted values

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=56)

# %%
X_test
# Out:
#       Temperature (°C)  Humidity (%)
# 2948             17.56         87.07
# 2707             31.08         42.13
# 6353             10.98         68.66
# 1281             23.73         38.15
# 5961              6.38         31.57
# ...                ...           ...
# 32               23.78         44.16
# 949              23.03         31.85
# 2279             20.32         66.56
# 4872             34.89         69.52
# 1607             27.95         73.08
#
# [1440 rows x 2 columns]

# %%
X_train
# Out:
#       Temperature (°C)  Humidity (%)
# 2705             -7.94         42.20
# 3790             15.82         41.41
# 2650             16.25         58.68
# 5261             19.33         33.94
# 3132             31.50         40.63
# ...                ...           ...
# 4931             24.63         45.86
# 3264             10.29         35.80
# 1653             -2.91         65.42
# 2607             26.47         55.66
# 2732              7.66         83.66
#
# [5760 rows x 2 columns]

# %%
y_test
# Out:
# 2948    369.29
# 2707    418.15
# 6353    341.21
# 1281     99.33
# 5961     82.24
#          ...
# 32      134.38
# 949     154.96
# 2279    405.25
# 4872    187.08
# 1607     88.69
# Name: Energy_Usage (kWh), Length: 1440, dtype: float64

# %%
y_train
# Out:
# 2705    373.45
# 3790    415.57
# 2650    302.21
# 5261    103.05
# 3132     78.01
#          ...
# 4931    157.20
# 3264    154.81
# 1653    258.40
# 2607    283.59
# 2732    341.70
# Name: Energy_Usage (kWh), Length: 5760, dtype: float64

# %%
#features scaling in data(for predictring values mei zyada farak naa aaye)
#z - score or standardization-(-3-3)
#normalization-always positive

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train
# Out:
# array([[-1.56370509, -1.03023594],
#        [ 0.26252435, -1.07622364],
#        [ 0.2955748 , -0.0708976 ],
#        ...,
#        [-1.1770917 ,  0.32145315],
#        [ 1.08109941, -0.24669868],
#        [-0.36466556,  1.38324509]])

# %%
X_test
# Out:
# array([[ 0.39626338,  1.58174896],
#        [ 1.43543097, -1.0343108 ],
#        [-0.10948535,  0.51006093],
#        ...,
#        [ 0.60840114,  0.38781515],
#        [ 1.72827331,  0.56012349],
#        [ 1.19485445,  0.7673592 ]])
