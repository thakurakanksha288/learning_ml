# %% [markdown]
# <a href="https://colab.research.google.com/github/thakurakanksha288/learning_ml/blob/main/learning_to_splitdata_in_test%26train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/carprices.csv')
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
from sklearn.model_selection import train_test_split
X = df[['Mileage','Age(yrs)']]
y = df['Sell Price($)']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=10)

# %%
len(X_train)
# Out:
# 14

# %%
len(X_test)
# Out:
# 6

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([20668.52722622, 16762.33242213, 25160.18381011, 27209.30003936,
#        37903.32633702, 14729.61531335])

# %%
y_test
# Out:
# 7     19300
# 10    18700
# 5     26750
# 6     32000
# 3     40000
# 18    12800
# Name: Sell Price($), dtype: int64

# %%
model.score(X_test,y_test)
# Out:
# 0.921242248377633
